# %%
import pandas as pd
import geopandas as gpd
from summaflow import (
    GeoLayer,
    SUMMAWorkflow,
    Stats,
)

import os
import glob

# %%
# paths
root_path = '../../bb-model-semidistributed/'

# layers' paths
landcover_path = os.path.join(root_path, 'attributes', 'landcover', 'MCD12Q1.061')
soilclass_path = os.path.join(root_path, 'attributes', 'soil')
merithdyr_path = os.path.join(root_path, 'attributes', 'elevation')

# geolayer's path
riv_path = os.path.join(root_path, 'shapefiles', 'bb_rivers_semidistributed.shp')
cat_path = os.path.join(root_path, 'shapefiles', 'bb_subbasins_semidistributed.shp')
hru_path = os.path.join(root_path, 'shapefiles', 'bb_subbasins_semidistributed.shp')

# forcings path
root_path_forcings = os.path.join(root_path, 'forcing', 'remapped')

# %%
# Geospatial layers
riv_obj = gpd.read_file(riv_path)
cat_obj = gpd.read_file(cat_path)
hru_obj = gpd.read_file(hru_path)

# %%
# layers needed by the setup workflow
# elevation
elv = GeoLayer.from_maf(
    maf_stats=os.path.join(merithdyr_path, 'bb_model_semidistributed_stats_elv.csv'),
    maf_layer=os.path.join(merithdyr_path, 'bb_model_semidistributed_elv.tif'),
    maf_geolayer=os.path.join(cat_path),
    unit = 'meters',
)
# landcover
landcover = GeoLayer.from_maf(
    maf_stats=os.path.join(landcover_path, 'bb_model_semidistributed_stats_MCD12Q1.061_2022.csv'),
    maf_layer=os.path.join(landcover_path, 'bb_model_semidistributed_2022.tif'),
    maf_geolayer=os.path.join(cat_path),
    unit = 'dimensionless',
)
# USDA soil classes
soil = GeoLayer.from_maf(
    maf_stats=os.path.join(soilclass_path, 'bb_model_semidistributed_stats_soil_classes.csv'),
    maf_layer=os.path.join(soilclass_path, 'bb_model_semidistributed_soil_classes.tif'),
    maf_geolayer=os.path.join(cat_path),
    unit = 'dimensionless',
)

# custom layers for `tan_slope`, `contourLength` and `downHRUindex`
# until relevant workflows are implemented inside `gistool`--sorry
# For now, look at various constructors for "GeoLayer"
slope = GeoLayer( # workflow needs `mean` stat
    stats=Stats(pd.DataFrame([0.1] * len(cat_obj), index=cat_obj['COMID'], columns=['mean'])),
    unit='dimensionless',
)
contour = GeoLayer( # workflow needs `length` stat
    stats=Stats(
        pd.DataFrame(
            cat_obj.set_crs(epsg=4326).to_crs('ESRI:54009').length, index=cat_obj['COMID'], columns=['length'])),
    unit='meter',
)
hru_index = GeoLayer( # workflow needs `index` "stat"
    stats=Stats(pd.DataFrame([0] * len(cat_obj), index=cat_obj['COMID'], columns=['index'])),
    unit='dimensionless',
)

# %%
exp = SUMMAWorkflow(
    forcing_data = glob.glob(os.path.join(root_path_forcings, '**', '*.nc'), recursive=True),
    forcing_name_mapping = {
        'CaSR_v3.1_A_PR0_SFC': 'pptrate',
        'CaSR_v3.1_P_TT_09975': 'airtemp',
        'CaSR_v3.1_P_P0_SFC': 'airpres',
        'CaSR_v3.1_P_FI_SFC': 'LWRadAtm',
        'CaSR_v3.1_P_FB_SFC': 'SWRadAtm',
        'CaSR_v3.1_P_HU_09975': 'spechum',
        'CaSR_v3.1_P_UVC_09975': 'windspd',
    },
    forcing_unit_mapping = {
        'pptrate': 'meter / hour',
        'airtemp': 'degC',
        'airpres': 'millibar',
        'LWRadAtm': 'watt / meter ** 2',
        'SWRadAtm': 'watt / meter ** 2',
        'spechum': 'dimensionless',
        'windspd': 'knot',
    },
    forcing_to_unit_mapping = {
        'pptrate': 'millimeter / second',
        'airtemp': 'kelvin',
        'airpres': 'pascal',
        'LWRadAtm': 'watt / meter ** 2',
        'SWRadAtm': 'watt / meter ** 2',
        'spechum': 'dimensionless',
        'windspd': 'meter / second',
    },
    forcing_attrs = {
        'measurement_height': 20,
        'measurement_height_unit': 'meter',
        'forcing_time_zone': 'utc', # original timezone of the forcing datatset
        'target_time_zone': 'utc', # if UTC, SUMMA converts to local time zone internally
        'local': {},
        'global': {},
    },
    topology_data = {
        'riv': riv_obj,
        'hru': hru_obj,
        'cat': cat_obj,
    },
    topology_unit_mapping = {}, # not sure if mizuRoute should be included here
    topology_to_unit_mapping = {}, # not sure if mizuRoute should be included here
    topology_attrs = {
        'gru_fid': 'COMID',
        'hru_fid': 'COMID',
        'local': {},
        'global': {},
    },
    geospatial_data = {
        'elevation': elv,
        'soilTypeIndex': soil,
        'vegTypeIndex': landcover,
        'tan_slope': slope,
        'contourLength': contour,
        'downHRUindex': hru_index,
    },
    cold_state = {
        'layers': {
            'nSoil': 8,
            'nSnow': 0,
        },
        'states': { # dimension manipulation is automated inside the workflow
            'scalarCanopyIce': 0,
            'scalarCanopyLiq': 0,
            'scalarSnowDepth': 0,
            'scalarSWE': 0,
            'scalarSfcMeltPond': 0,
            'scalarAquiferStorage': 0.4,
            'scalarSnowAlbedo': 0,
            'scalarCanairTemp': 283.16,
            'scalarCanopyTemp': 283.16,
            'mLayerTemp': 283.16,
            'mLayerVolFracIce': 0,
            'mLayerVolFracLiq': 0.4,
            'mLayerMatricHead': -1.0,
            'mLayerDepth': [0.025, 0.075, 0.15, 0.25, 0.5, 0.5, 1, 1.5],
        },
    },
    decisions = { # Can change all decisions, otherwise default values
        'soilCatTbl': 'ROSETTA',
    },
    auxillary = {
        # 'dt_init': 450 # if not provided, defaults to forcing data timestep
    },
    settings = {
        'model_path': os.path.join(root_path, 'settings', 'SUMMA'),
        'start_date': '1980-01-01 00:00',
        'end_date': '1980-01-10 23:00',
        'verbose': True,
    },
    fillna = {
        'geospatial_data': {
            'elevation': 1, # a rough assumption--can be modified to anything
            'soilTypeIndex': 6, # based on Darri's assumption--can be modified to anything
            'vegTypeIndex': 1, # a rough assumption--can be modified to anything
        },
    },
)
# Out:
# 2025-06-02 11:58:13,022 - summaflow.core - INFO - SUMMA workflow initialized
# /home/kasra.keshavarz1/virtual-envs/summaflow/lib/python3.11/site-packages/summaflow/core.py:267: UserWarning: `dt_init` not provided in auxillary dictionary; defaulting to forcing time-step.
#   warnings.warn("`dt_init` not provided in auxillary dictionary;"

# %% [markdown]
# ## Workflow tests

# %%
exp.run(path=os.path.join(root_path), save=True)
# Out:
# 2025-06-02 11:58:13,026 - summaflow.core - INFO - Running SUMMA workflow
# 2025-06-02 11:58:13,461 - summaflow.core - INFO - Initializing attributes for SUMMA workflow...
# 2025-06-02 11:58:13,462 - summaflow.core - INFO - Creating attributes xarray.Dataset
# 2025-06-02 11:58:13,463 - summaflow.core - INFO - Adding `mHeight` attribute
# 2025-06-02 11:58:13,464 - summaflow.core - INFO - Adding `slopeTypeIndex` attribute
# 2025-06-02 11:58:13,465 - summaflow.core - INFO - Adding `hruId` and `gruId` attributes
# 2025-06-02 11:58:13,467 - summaflow.core - INFO - Adding `hru2gruId` attributes
# 2025-06-02 11:58:13,473 - summaflow.core - INFO - Calculating and adding `latitude` and `logitude` attributes
# 2025-06-02 11:58:13,485 - summaflow.core - INFO - Calculating and adding `area` attributes
# /home/kasra.keshavarz1/virtual-envs/summaflow/lib/python3.11/site-packages/summaflow/utils.py:138: UserWarning: Using EPSG:3857 for centroid calculations on geographic data. For better accuracy, specify a local projection using calculation_crs parameter.
#   warnings.warn(
# 2025-06-02 11:58:13,769 - summaflow.core - INFO - Adding geospatial layers' attributes
# 2025-06-02 11:58:13,770 - summaflow.core - INFO - Adding `tan_slope` attributes
# 2025-06-02 11:58:13,772 - summaflow.core - INFO - Adding `contourLength` attributes
# 2025-06-02 11:58:13,773 - summaflow.core - INFO - Adding `downHRUindex` attributes
# 2025-06-02 11:58:13,775 - summaflow.core - INFO - Adding `elevation` attributes
# 2025-06-02 11:58:13,776 - summaflow.core - INFO - Adding `vegTypeIndex` attributes
# 2025-06-02 11:58:13,778 - summaflow.core - INFO - Adding `soilTypeIndex` attributes
# 2025-06-02 11:58:13,783 - summaflow.core - INFO - Adding local and global attributes of the Dataset
# 2025-06-02 11:58:13,783 - summaflow.core - INFO - SUMMA attributes initialized successfully.
# 2025-06-02 11:58:13,784 - summaflow.core - INFO - Saving dataset to /home/kasra.keshavarz1/github-repos/bow-river-at-banff/bb-model-semidistributed/settings/SUMMA/attributes.nc
# 2025-06-02 11:58:13,843 - summaflow.core - INFO - Initializing attributes for SUMMA workflow...
# 2025-06-02 11:58:13,843 - summaflow.core - INFO - Assigning timezone
# 2025-06-02 11:58:14,329 - summaflow.core - INFO - Processing forcing file: remapped_remapped_bb_model_semidistributed_1979123112.nc
# 2025-06-02 11:58:14,435 - summaflow.core - INFO - Saving dataset to /home/kasra.keshavarz1/github-repos/bow-river-at-banff/bb-model-semidistributed/forcing/SUMMA/remapped_remapped_bb_model_semidistributed_1979123112.nc
# 2025-06-02 11:58:14,529 - summaflow.core - INFO - Processing forcing file: remapped_remapped_bb_model_semidistributed_1980010112.nc
# 2025-06-02 11:58:14,567 - summaflow.core - INFO - Saving dataset to /home/kasra.keshavarz1/github-repos/bow-river-at-banff/bb-model-semidistributed/forcing/SUMMA/remapped_remapped_bb_model_semidistributed_1980010112.nc
# 2025-06-02 11:58:14,617 - summaflow.core - INFO - Processing forcing file: remapped_remapped_bb_model_semidistributed_1980010212.nc
# 2025-06-02 11:58:14,645 - summaflow.core - INFO - Saving dataset to /home/kasra.keshavarz1/github-repos/bow-river-at-banff/bb-model-semidistributed/forcing/SUMMA/remapped_remapped_bb_model_semidistributed_1980010212.nc
# 2025-06-02 11:58:14,682 - summaflow.core - INFO - Processing forcing file: remapped_remapped_bb_model_semidistributed_1980010312.nc
# 2025-06-02 11:58:14,713 - summaflow.core - INFO - Saving dataset to /home/kasra.keshavarz1/github-repos/bow-river-at-banff/bb-model-semidistributed/forcing/SUMMA/remapped_remapped_bb_model_semidistributed_1980010312.nc
# 2025-06-02 11:58:14,759 - summaflow.core - INFO - Processing forcing file: remapped_remapped_bb_model_semidistributed_1980010412.nc
# 2025-06-02 11:58:14,787 - summaflow.core - INFO - Saving dataset to /home/kasra.keshavarz1/github-repos/bow-river-at-banff/bb-model-semidistributed/forcing/SUMMA/remapped_remapped_bb_model_semidistributed_1980010412.nc
# 2025-06-02 11:58:14,824 - summaflow.core - INFO - Processing forcing file: remapped_remapped_bb_model_semidistributed_1980010512.nc
# 2025-06-02 11:58:14,852 - summaflow.core - INFO - Saving dataset to /home/kasra.keshavarz1/github-repos/bow-river-at-banff/bb-model-semidistributed/forcing/SUMMA/remapped_remapped_bb_model_semidistributed_1980010512.nc
# 2025-06-02 11:58:14,891 - summaflow.core - INFO - Processing forcing file: remapped_remapped_bb_model_semidistributed_1980010612.nc
# 2025-06-02 11:58:14,917 - summaflow.core - INFO - Saving dataset to /home/kasra.keshavarz1/github-repos/bow-river-at-banff/bb-model-semidistributed/forcing/SUMMA/remapped_remapped_bb_model_semidistributed_1980010612.nc
# 2025-06-02 11:58:14,961 - summaflow.core - INFO - Processing forcing file: remapped_remapped_bb_model_semidistributed_1980010712.nc
# 2025-06-02 11:58:14,994 - summaflow.core - INFO - Saving dataset to /home/kasra.keshavarz1/github-repos/bow-river-at-banff/bb-model-semidistributed/forcing/SUMMA/remapped_remapped_bb_model_semidistributed_1980010712.nc
# 2025-06-02 11:58:15,026 - summaflow.core - INFO - Processing forcing file: remapped_remapped_bb_model_semidistributed_1980010812.nc
# 2025-06-02 11:58:15,232 - summaflow.core - INFO - Saving dataset to /home/kasra.keshavarz1/github-repos/bow-river-at-banff/bb-model-semidistributed/forcing/SUMMA/remapped_remapped_bb_model_semidistributed_1980010812.nc
# 2025-06-02 11:58:15,265 - summaflow.core - INFO - Processing forcing file: remapped_remapped_bb_model_semidistributed_1980010912.nc
# 2025-06-02 11:58:15,292 - summaflow.core - INFO - Saving dataset to /home/kasra.keshavarz1/github-repos/bow-river-at-banff/bb-model-semidistributed/forcing/SUMMA/remapped_remapped_bb_model_semidistributed_1980010912.nc
# 2025-06-02 11:58:15,327 - summaflow.core - INFO - Processing forcing file: remapped_remapped_bb_model_semidistributed_1980011012.nc
# 2025-06-02 11:58:15,350 - summaflow.core - INFO - Saving dataset to /home/kasra.keshavarz1/github-repos/bow-river-at-banff/bb-model-semidistributed/forcing/SUMMA/remapped_remapped_bb_model_semidistributed_1980011012.nc
# 2025-06-02 11:58:15,379 - summaflow.core - INFO - Forcing dataset processed/initialized successfully.
# 2025-06-02 11:58:15,379 - summaflow.core - INFO - Initializing cold state
# 2025-06-02 11:58:15,380 - summaflow.core - INFO - Calculating `iLayerHeight` from `mLayerDepth`
# 2025-06-02 11:58:15,380 - summaflow.core - INFO - Calculating dimensions for cold state
# 2025-06-02 11:58:15,380 - summaflow.core - INFO - Calculating `midToto`
# 2025-06-02 11:58:15,381 - summaflow.core - INFO - Calculating `midSoil`
# 2025-06-02 11:58:15,381 - summaflow.core - INFO - Calculating `ifcToto`
# 2025-06-02 11:58:15,381 - summaflow.core - INFO - Assigning `scalarv` to 1
# 2025-06-02 11:58:15,382 - summaflow.core - INFO - Adding variables: `hruId`, `dt_init`, `nSoil`, and `nSnow`
# 2025-06-02 11:58:15,382 - summaflow.core - INFO - Adding variables: `scalarCanopyIce`
# 2025-06-02 11:58:15,382 - summaflow.core - INFO -     dimensions: ('scalarv', 'hru') with lengths [1, 51]
# 2025-06-02 11:58:15,383 - summaflow.core - INFO - Adding variables: `scalarCanopyLiq`
# 2025-06-02 11:58:15,383 - summaflow.core - INFO -     dimensions: ('scalarv', 'hru') with lengths [1, 51]
# 2025-06-02 11:58:15,383 - summaflow.core - INFO - Adding variables: `scalarSnowDepth`
# 2025-06-02 11:58:15,384 - summaflow.core - INFO -     dimensions: ('scalarv', 'hru') with lengths [1, 51]
# 2025-06-02 11:58:15,384 - summaflow.core - INFO - Adding variables: `scalarSWE`
# 2025-06-02 11:58:15,384 - summaflow.core - INFO -     dimensions: ('scalarv', 'hru') with lengths [1, 51]
# 2025-06-02 11:58:15,384 - summaflow.core - INFO - Adding variables: `scalarSfcMeltPond`
# 2025-06-02 11:58:15,385 - summaflow.core - INFO -     dimensions: ('scalarv', 'hru') with lengths [1, 51]
# 2025-06-02 11:58:15,385 - summaflow.core - INFO - Adding variables: `scalarAquiferStorage`
# 2025-06-02 11:58:15,385 - summaflow.core - INFO -     dimensions: ('scalarv', 'hru') with lengths [1, 51]
# 2025-06-02 11:58:15,386 - summaflow.core - INFO - Adding variables: `scalarSnowAlbedo`
# 2025-06-02 11:58:15,386 - summaflow.core - INFO -     dimensions: ('scalarv', 'hru') with lengths [1, 51]
# 2025-06-02 11:58:15,386 - summaflow.core - INFO - Adding variables: `scalarCanairTemp`
# 2025-06-02 11:58:15,387 - summaflow.core - INFO -     dimensions: ('scalarv', 'hru') with lengths [1, 51]
# 2025-06-02 11:58:15,387 - summaflow.core - INFO - Adding variables: `scalarCanopyTemp`
# 2025-06-02 11:58:15,387 - summaflow.core - INFO -     dimensions: ('scalarv', 'hru') with lengths [1, 51]
# 2025-06-02 11:58:15,388 - summaflow.core - INFO - Adding variables: `mLayerTemp`
# 2025-06-02 11:58:15,388 - summaflow.core - INFO -     dimensions: ('midToto', 'hru') with lengths [8, 51]
# 2025-06-02 11:58:15,388 - summaflow.core - INFO - Adding variables: `mLayerVolFracIce`
# 2025-06-02 11:58:15,388 - summaflow.core - INFO -     dimensions: ('midToto', 'hru') with lengths [8, 51]
# 2025-06-02 11:58:15,389 - summaflow.core - INFO - Adding variables: `mLayerVolFracLiq`
# 2025-06-02 11:58:15,389 - summaflow.core - INFO -     dimensions: ('midToto', 'hru') with lengths [8, 51]
# 2025-06-02 11:58:15,389 - summaflow.core - INFO - Adding variables: `mLayerMatricHead`
# 2025-06-02 11:58:15,389 - summaflow.core - INFO -     dimensions: ('midSoil', 'hru') with lengths [8, 51]
# 2025-06-02 11:58:15,390 - summaflow.core - INFO - Adding variables: `mLayerDepth`
# 2025-06-02 11:58:15,390 - summaflow.core - INFO -     dimensions: ('midToto', 'hru') with lengths [8, 51]
# 2025-06-02 11:58:15,390 - summaflow.core - INFO - Adding variables: `iLayerHeight`
# 2025-06-02 11:58:15,391 - summaflow.core - INFO -     dimensions: ('ifcToto', 'hru') with lengths [9, 51]
# 2025-06-02 11:58:15,391 - summaflow.core - INFO - Adding variables to the `cold_state` Dataset
# 2025-06-02 11:58:15,392 - summaflow.core - INFO - Updating `cold_state` Dataset's local and global attributes
# 2025-06-02 11:58:15,393 - summaflow.core - INFO - Reordering `cold_state` hrus and grus to match dimensions of `attrs`
# 2025-06-02 11:58:15,395 - summaflow.core - INFO - Saving dataset to /home/kasra.keshavarz1/github-repos/bow-river-at-banff/bb-model-semidistributed/settings/SUMMA/coldState.nc
# 2025-06-02 11:58:15,420 - summaflow.core - INFO - Preparing trial parameters Dataset
# 2025-06-02 11:58:15,421 - summaflow.core - INFO - Adding `hru` and `gru` dimensions to the Dataset
# 2025-06-02 11:58:15,421 - summaflow.core - INFO - Adding `hruId` and `gruId` variables to the Dataset
# 2025-06-02 11:58:15,422 - summaflow.core - INFO - Updating `trial_params` Dataset's local and global attributes
# 2025-06-02 11:58:15,422 - summaflow.core - INFO - Reordering `trial_params` hrus and grus to match dimensions of `attrs`
# 2025-06-02 11:58:15,423 - summaflow.core - INFO - Trial parameters Dataset initialized successfully.
# 2025-06-02 11:58:15,424 - summaflow.core - INFO - Saving dataset to /home/kasra.keshavarz1/github-repos/bow-river-at-banff/bb-model-semidistributed/settings/SUMMA/trialParams.nc
# 2025-06-02 11:58:15,431 - summaflow.core - INFO - Preparing model decisions
# 2025-06-02 11:58:15,443 - summaflow.core - INFO - Populating default model decisions
# 2025-06-02 11:58:15,444 - summaflow.core - INFO - Rendering model decisions template
# 2025-06-02 11:58:15,446 - summaflow.core - INFO - Model decisions rendered successfully.
# 2025-06-02 11:58:15,447 - summaflow.core - INFO - Preparing template files to copy if instructed
# 2025-06-02 11:58:15,448 - summaflow.core - INFO - Target path is: /home/kasra.keshavarz1/github-repos/bow-river-at-banff/bb-model-semidistributed/settings/SUMMA/
# 2025-06-02 11:58:15,450 - summaflow.core - INFO - Copying file: README
# 2025-06-02 11:58:15,454 - summaflow.core - INFO - Copying file: TBL_GENPARM.TBL
# 2025-06-02 11:58:15,457 - summaflow.core - INFO - Copying file: TBL_MPTABLE.TBL
# 2025-06-02 11:58:15,462 - summaflow.core - INFO - Copying file: TBL_SOILPARM.TBL
# 2025-06-02 11:58:15,465 - summaflow.core - INFO - Copying file: TBL_VEGPARM.TBL
# 2025-06-02 11:58:15,469 - summaflow.core - INFO - Copying file: basinParamInfo.txt
# 2025-06-02 11:58:15,473 - summaflow.core - INFO - Copying file: localParamInfo.txt
# 2025-06-02 11:58:15,477 - summaflow.core - INFO - Copying file: outputControl.txt
# 2025-06-02 11:58:15,480 - summaflow.core - INFO - Template files initialized successfully.
